# %% [markdown]
# # Data collection and storage

# %%
# Import the modules we need.
from bs4 import BeautifulSoup
from bs4 import SoupStrainer
import datetime
from glob import glob
import json
import os
import re
import requests
import string
import sys
import time


# Path to the data directory into which downloaded JSON is saved.
data_path = os.path.join(".", "data", "raw_data", "movie_reviews")
print(data_path)

# Check for whether os.path exists or not, if not create the dicrectory path
if not os.path.exists(data_path):
    print("Creating data directory: {}".format(data_path))
    os.makedirs(data_path)

if os.path.isdir(data_path):
    print(data_path + " is a directory")
else:
    print(data_path + " is NOT a directory - something is wrong :(")


# NYT API Key needs to be set in the environment before running this notebook.
nyt_archive_key = os.getenv('nyt_archive_key')
#print(nyt_archive_key)

if (nyt_archive_key is None) or (nyt_archive_key == ''):
    print("NYT API key is missing - it should be in an environment variable named 'nyt_archive_key'")
# Out:
# .\data\raw_data\movie_reviews
# .\data\raw_data\movie_reviews is a directory

# %%
# General-purpose utility function for saving an object as JSON to the data directory.
def save_to_json(obj, save_file_path):
    print("saving to file: " + save_file_path)

    with open(save_file_path, "wt") as f:
        json.dump(obj, f)
        
# General function for getting JSON, either by downloading or from a cache file.
def resolve_nyt_json(url, cache_file, request_params={}):
    if os.path.isfile(cache_file):
        # Cache file exists, so use that.
        result = {}
        with open(cache_file, 'rt') as f:
            try:
                result = json.load(f)
            except ValueError:
                result = {}
                
        print("resolve_nyt_json(): returning value from cache file: " + cache_file)
        return result

    # It's not in the cache, so download and save it.
    print("resolve_nyt_json(): downloading from NYT API")

    response = requests.get(url, params=request_params)
    print(response.status_code)
        
    # Sleep after a request, to avoid being rate-limited by the NYT servers.
    time.sleep(5)
    
    if 200 == response.status_code:
        save_to_json(response.json(), cache_file)
    else:
        print("resolve_nyt_json(): error downloading from NYT API ({code})".format(code=response.status_code))
        return {}
        
    return response.json()

# %%
# URL for calls to movies/v7/reviews
def get_movie_reviews_url():
    return "https://api.nytimes.com/svc/movies/v2/reviews/all.json"

# Name of the cache file for calls to reviews/search.
def get_movie_reviews_cache_file_path(offset):
    filename = "movie_reviews_{offset}.json".format(offset=offset)
    print(filename)
    return os.path.join(data_path, filename)

# Name of the cache file for calls to reviews/search.
def get_movie_reviews_params(offset):
    return {'api-key':nyt_archive_key, 
            'offset':offset}

# Convenience routine for getting the result of movie reviews search.
def resolve_movie_reviews(offset):
    return resolve_nyt_json(get_movie_reviews_url(), 
                            get_movie_reviews_cache_file_path(offset), 
                            get_movie_reviews_params(offset))

# %%
# set offset to deal with rate limied 
offset = 0
has_more_reviews = True
while has_more_reviews:
    response = resolve_movie_reviews(offset)
    try:
        has_more_reviews = response['has_more']
        offset += 20
    except:
        # Probably got rate-limited. Sleep and try again...
        time.sleep(60)
    
print("Finished")
# Out:
# movie_reviews_0.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_0.json
# movie_reviews_20.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_20.json
# movie_reviews_40.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_40.json
# movie_reviews_60.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_60.json
# movie_reviews_80.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_80.json
# movie_reviews_100.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_100.json
# movie_reviews_120.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_120.json
# movie_reviews_140.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_140.json
# movie_reviews_160.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_160.json
# movie_reviews_180.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_180.json
# movie_reviews_200.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_200.json
# movie_reviews_220.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_220.json
# movie_reviews_240.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_240.json
# movie_reviews_260.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_260.json
# movie_reviews_280.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_280.json
# movie_reviews_300.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_300.json
# movie_reviews_320.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_320.json
# movie_reviews_340.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_340.json
# movie_reviews_360.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_360.json
# movie_reviews_380.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_380.json
# movie_reviews_400.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_400.json
# movie_reviews_420.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_420.json
# movie_reviews_440.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_440.json
# movie_reviews_460.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_460.json
# movie_reviews_480.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_480.json
# movie_reviews_500.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_500.json
# movie_reviews_520.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_520.json
# movie_reviews_540.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_540.json
# movie_reviews_560.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_560.json
# movie_reviews_580.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_580.json
# movie_reviews_600.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_600.json
# movie_reviews_620.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_620.json
# movie_reviews_640.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_640.json
# movie_reviews_660.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_660.json
# movie_reviews_680.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_680.json
# movie_reviews_700.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_700.json
# movie_reviews_720.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_720.json
# movie_reviews_740.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_740.json
# movie_reviews_760.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_760.json
# movie_reviews_780.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_780.json
# movie_reviews_800.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_800.json
# movie_reviews_820.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_820.json
# movie_reviews_840.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_840.json
# movie_reviews_860.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_860.json
# movie_reviews_880.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_880.json
# movie_reviews_900.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_900.json
# movie_reviews_920.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_920.json
# movie_reviews_940.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_940.json
# movie_reviews_960.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_960.json
# movie_reviews_980.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_980.json
# movie_reviews_1000.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_1000.json
# movie_reviews_1020.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_1020.json
# movie_reviews_1040.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_1040.json
# movie_reviews_1060.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_1060.json
# movie_reviews_1080.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_1080.json
# movie_reviews_1100.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_1100.json
# movie_reviews_1120.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_1120.json
# movie_reviews_1140.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_1140.json
# movie_reviews_1160.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_1160.json
# movie_reviews_1180.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_1180.json
# movie_reviews_1200.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_1200.json
# movie_reviews_1220.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_1220.json
# movie_reviews_1240.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_1240.json
# movie_reviews_1260.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_1260.json
# movie_reviews_1280.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_1280.json
# movie_reviews_1300.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_1300.json
# movie_reviews_1320.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_1320.json
# movie_reviews_1340.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_1340.json
# movie_reviews_1360.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_1360.json
# movie_reviews_1380.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_1380.json
# movie_reviews_1400.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_1400.json
# movie_reviews_1420.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_1420.json
# movie_reviews_1440.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_1440.json
# movie_reviews_1460.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_1460.json
# movie_reviews_1480.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_1480.json
# movie_reviews_1500.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_1500.json
# movie_reviews_1520.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_1520.json
# movie_reviews_1540.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_1540.json
# movie_reviews_1560.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_1560.json
# movie_reviews_1580.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_1580.json
# movie_reviews_1600.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_1600.json
# movie_reviews_1620.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_1620.json
# movie_reviews_1640.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_1640.json
# movie_reviews_1660.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_1660.json
# movie_reviews_1680.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_1680.json
# movie_reviews_1700.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_1700.json
# movie_reviews_1720.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_1720.json
# movie_reviews_1740.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_1740.json
# movie_reviews_1760.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_1760.json
# movie_reviews_1780.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_1780.json
# movie_reviews_1800.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_1800.json
# movie_reviews_1820.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_1820.json
# movie_reviews_1840.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_1840.json
# movie_reviews_1860.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_1860.json
# movie_reviews_1880.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_1880.json
# movie_reviews_1900.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_1900.json
# movie_reviews_1920.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_1920.json
# movie_reviews_1940.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_1940.json
# movie_reviews_1960.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_1960.json
# movie_reviews_1980.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_1980.json
# movie_reviews_2000.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_2000.json
# movie_reviews_2020.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_2020.json
# movie_reviews_2040.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_2040.json
# movie_reviews_2060.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_2060.json
# movie_reviews_2080.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_2080.json
# movie_reviews_2100.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_2100.json
# movie_reviews_2120.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_2120.json
# movie_reviews_2140.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_2140.json
# movie_reviews_2160.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_2160.json
# movie_reviews_2180.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_2180.json
# movie_reviews_2200.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_2200.json
# movie_reviews_2220.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_2220.json
# movie_reviews_2240.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_2240.json
# movie_reviews_2260.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_2260.json
# movie_reviews_2280.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_2280.json
# movie_reviews_2300.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_2300.json
# movie_reviews_2320.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_2320.json
# movie_reviews_2340.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_2340.json
# movie_reviews_2360.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_2360.json
# movie_reviews_2380.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_2380.json
# movie_reviews_2400.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_2400.json
# movie_reviews_2420.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_2420.json
# movie_reviews_2440.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_2440.json
# movie_reviews_2460.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_2460.json
# movie_reviews_2480.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_2480.json
# movie_reviews_2500.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_2500.json
# movie_reviews_2520.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_2520.json
# movie_reviews_2540.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_2540.json
# movie_reviews_2560.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_2560.json
# movie_reviews_2580.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_2580.json
# movie_reviews_2600.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_2600.json
# movie_reviews_2620.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_2620.json
# movie_reviews_2640.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_2640.json
# movie_reviews_2660.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_2660.json
# movie_reviews_2680.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_2680.json
# movie_reviews_2700.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_2700.json
# movie_reviews_2720.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_2720.json
# movie_reviews_2740.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_2740.json
# movie_reviews_2760.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_2760.json
# movie_reviews_2780.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_2780.json
# movie_reviews_2800.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_2800.json
# movie_reviews_2820.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_2820.json
# movie_reviews_2840.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_2840.json
# movie_reviews_2860.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_2860.json
# movie_reviews_2880.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_2880.json
# movie_reviews_2900.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_2900.json
# movie_reviews_2920.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_2920.json
# movie_reviews_2940.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_2940.json
# movie_reviews_2960.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_2960.json
# movie_reviews_2980.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_2980.json
# movie_reviews_3000.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_3000.json
# movie_reviews_3020.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_3020.json
# movie_reviews_3040.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_3040.json
# movie_reviews_3060.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_3060.json
# movie_reviews_3080.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_3080.json
# movie_reviews_3100.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_3100.json
# movie_reviews_3120.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_3120.json
# movie_reviews_3140.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_3140.json
# movie_reviews_3160.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_3160.json
# movie_reviews_3180.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_3180.json
# movie_reviews_3200.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_3200.json
# movie_reviews_3220.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_3220.json
# movie_reviews_3240.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_3240.json
# movie_reviews_3260.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_3260.json
# movie_reviews_3280.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_3280.json
# movie_reviews_3300.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_3300.json
# movie_reviews_3320.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_3320.json
# movie_reviews_3340.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_3340.json
# movie_reviews_3360.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_3360.json
# movie_reviews_3380.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_3380.json
# movie_reviews_3400.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_3400.json
# movie_reviews_3420.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_3420.json
# movie_reviews_3440.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_3440.json
# movie_reviews_3460.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_3460.json
# movie_reviews_3480.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_3480.json
# movie_reviews_3500.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_3500.json
# movie_reviews_3520.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_3520.json
# movie_reviews_3540.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_3540.json
# movie_reviews_3560.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_3560.json
# movie_reviews_3580.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_3580.json
# movie_reviews_3600.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_3600.json
# movie_reviews_3620.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_3620.json
# movie_reviews_3640.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_3640.json
# movie_reviews_3660.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_3660.json
# movie_reviews_3680.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_3680.json
# movie_reviews_3700.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_3700.json
# movie_reviews_3720.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_3720.json
# movie_reviews_3740.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_3740.json
# movie_reviews_3760.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_3760.json
# movie_reviews_3780.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_3780.json
# movie_reviews_3800.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_3800.json
# movie_reviews_3820.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_3820.json
# movie_reviews_3840.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_3840.json
# movie_reviews_3860.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_3860.json
# movie_reviews_3880.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_3880.json
# movie_reviews_3900.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_3900.json
# movie_reviews_3920.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_3920.json
# movie_reviews_3940.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_3940.json
# movie_reviews_3960.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_3960.json
# movie_reviews_3980.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_3980.json
# movie_reviews_4000.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_4000.json
# movie_reviews_4020.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_4020.json
# movie_reviews_4040.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_4040.json
# movie_reviews_4060.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_4060.json
# movie_reviews_4080.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_4080.json
# movie_reviews_4100.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_4100.json
# movie_reviews_4120.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_4120.json
# movie_reviews_4140.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_4140.json
# movie_reviews_4160.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_4160.json
# movie_reviews_4180.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_4180.json
# movie_reviews_4200.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_4200.json
# movie_reviews_4220.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_4220.json
# movie_reviews_4240.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_4240.json
# movie_reviews_4260.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_4260.json
# movie_reviews_4280.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_4280.json
# movie_reviews_4300.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_4300.json
# movie_reviews_4320.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_4320.json
# movie_reviews_4340.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_4340.json
# movie_reviews_4360.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_4360.json
# movie_reviews_4380.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_4380.json
# movie_reviews_4400.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_4400.json
# movie_reviews_4420.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_4420.json
# movie_reviews_4440.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_4440.json
# movie_reviews_4460.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_4460.json
# movie_reviews_4480.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_4480.json
# movie_reviews_4500.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_4500.json
# movie_reviews_4520.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_4520.json
# movie_reviews_4540.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_4540.json
# movie_reviews_4560.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_4560.json
# movie_reviews_4580.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_4580.json
# movie_reviews_4600.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_4600.json
# movie_reviews_4620.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_4620.json
# movie_reviews_4640.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_4640.json
# movie_reviews_4660.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_4660.json
# movie_reviews_4680.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_4680.json
# movie_reviews_4700.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_4700.json
# movie_reviews_4720.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_4720.json
# movie_reviews_4740.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_4740.json
# movie_reviews_4760.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_4760.json
# movie_reviews_4780.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_4780.json
# movie_reviews_4800.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_4800.json
# movie_reviews_4820.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_4820.json
# movie_reviews_4840.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_4840.json
# movie_reviews_4860.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_4860.json
# movie_reviews_4880.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_4880.json
# movie_reviews_4900.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_4900.json
# movie_reviews_4920.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_4920.json
# movie_reviews_4940.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_4940.json
# movie_reviews_4960.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_4960.json
# movie_reviews_4980.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_4980.json
# movie_reviews_5000.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_5000.json
# movie_reviews_5020.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_5020.json
# movie_reviews_5040.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_5040.json
# movie_reviews_5060.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_5060.json
# movie_reviews_5080.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_5080.json
# movie_reviews_5100.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_5100.json
# movie_reviews_5120.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_5120.json
# movie_reviews_5140.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_5140.json
# movie_reviews_5160.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_5160.json
# movie_reviews_5180.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_5180.json
# movie_reviews_5200.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_5200.json
# movie_reviews_5220.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_5220.json
# movie_reviews_5240.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_5240.json
# movie_reviews_5260.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_5260.json
# movie_reviews_5280.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_5280.json
# movie_reviews_5300.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_5300.json
# movie_reviews_5320.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_5320.json
# movie_reviews_5340.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_5340.json
# movie_reviews_5360.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_5360.json
# movie_reviews_5380.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_5380.json
# movie_reviews_5400.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_5400.json
# movie_reviews_5420.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_5420.json
# movie_reviews_5440.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_5440.json
# movie_reviews_5460.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_5460.json
# movie_reviews_5480.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_5480.json
# movie_reviews_5500.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_5500.json
# movie_reviews_5520.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_5520.json
# movie_reviews_5540.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_5540.json
# movie_reviews_5560.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_5560.json
# movie_reviews_5580.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_5580.json
# movie_reviews_5600.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_5600.json
# movie_reviews_5620.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_5620.json
# movie_reviews_5640.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_5640.json
# movie_reviews_5660.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_5660.json
# movie_reviews_5680.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_5680.json
# movie_reviews_5700.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_5700.json
# movie_reviews_5720.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_5720.json
# movie_reviews_5740.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_5740.json
# movie_reviews_5760.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_5760.json
# movie_reviews_5780.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_5780.json
# movie_reviews_5800.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_5800.json
# movie_reviews_5820.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_5820.json
# movie_reviews_5840.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_5840.json
# movie_reviews_5860.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_5860.json
# movie_reviews_5880.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_5880.json
# movie_reviews_5900.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_5900.json
# movie_reviews_5920.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_5920.json
# movie_reviews_5940.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_5940.json
# movie_reviews_5960.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_5960.json
# movie_reviews_5980.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_5980.json
# movie_reviews_6000.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_6000.json
# movie_reviews_6020.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_6020.json
# movie_reviews_6040.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_6040.json
# movie_reviews_6060.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_6060.json
# movie_reviews_6080.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_6080.json
# movie_reviews_6100.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_6100.json
# movie_reviews_6120.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_6120.json
# movie_reviews_6140.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_6140.json
# movie_reviews_6160.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_6160.json
# movie_reviews_6180.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_6180.json
# movie_reviews_6200.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_6200.json
# movie_reviews_6220.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_6220.json
# movie_reviews_6240.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_6240.json
# movie_reviews_6260.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_6260.json
# movie_reviews_6280.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_6280.json
# movie_reviews_6300.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_6300.json
# movie_reviews_6320.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_6320.json
# movie_reviews_6340.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_6340.json
# movie_reviews_6360.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_6360.json
# movie_reviews_6380.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_6380.json
# movie_reviews_6400.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_6400.json
# movie_reviews_6420.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_6420.json
# movie_reviews_6440.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_6440.json
# movie_reviews_6460.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_6460.json
# movie_reviews_6480.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_6480.json
# movie_reviews_6500.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_6500.json
# movie_reviews_6520.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_6520.json
# movie_reviews_6540.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_6540.json
# movie_reviews_6560.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_6560.json
# movie_reviews_6580.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_6580.json
# movie_reviews_6600.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_6600.json
# movie_reviews_6620.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_6620.json
# movie_reviews_6640.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_6640.json
# movie_reviews_6660.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_6660.json
# movie_reviews_6680.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_6680.json
# movie_reviews_6700.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_6700.json
# movie_reviews_6720.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_6720.json
# movie_reviews_6740.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_6740.json
# movie_reviews_6760.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_6760.json
# movie_reviews_6780.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_6780.json
# movie_reviews_6800.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_6800.json
# movie_reviews_6820.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_6820.json
# movie_reviews_6840.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_6840.json
# movie_reviews_6860.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_6860.json
# movie_reviews_6880.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_6880.json
# movie_reviews_6900.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_6900.json
# movie_reviews_6920.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_6920.json
# movie_reviews_6940.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_6940.json
# movie_reviews_6960.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_6960.json
# movie_reviews_6980.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_6980.json
# movie_reviews_7000.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_7000.json
# movie_reviews_7020.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_7020.json
# movie_reviews_7040.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_7040.json
# movie_reviews_7060.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_7060.json
# movie_reviews_7080.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_7080.json
# movie_reviews_7100.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_7100.json
# movie_reviews_7120.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_7120.json
# movie_reviews_7140.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_7140.json
# movie_reviews_7160.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_7160.json
# movie_reviews_7180.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_7180.json
# movie_reviews_7200.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_7200.json
# movie_reviews_7220.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_7220.json
# movie_reviews_7240.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_7240.json
# movie_reviews_7260.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_7260.json
# movie_reviews_7280.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_7280.json
# movie_reviews_7300.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_7300.json
# movie_reviews_7320.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_7320.json
# movie_reviews_7340.json
# ...
# movie_reviews_24500.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_24500.json
# movie_reviews_24520.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_24520.json
# movie_reviews_24540.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_24540.json
# movie_reviews_24560.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_24560.json
# movie_reviews_24580.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_24580.json
# movie_reviews_24600.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_24600.json
# movie_reviews_24620.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_24620.json
# movie_reviews_24640.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_24640.json
# movie_reviews_24660.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_24660.json
# movie_reviews_24680.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_24680.json
# movie_reviews_24700.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_24700.json
# movie_reviews_24720.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_24720.json
# movie_reviews_24740.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_24740.json
# movie_reviews_24760.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_24760.json
# movie_reviews_24780.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_24780.json
# movie_reviews_24800.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_24800.json
# movie_reviews_24820.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_24820.json
# movie_reviews_24840.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_24840.json
# movie_reviews_24860.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_24860.json
# movie_reviews_24880.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_24880.json
# movie_reviews_24900.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_24900.json
# movie_reviews_24920.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_24920.json
# movie_reviews_24940.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_24940.json
# movie_reviews_24960.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_24960.json
# movie_reviews_24980.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_24980.json
# movie_reviews_25000.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_25000.json
# movie_reviews_25020.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_25020.json
# movie_reviews_25040.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_25040.json
# movie_reviews_25060.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_25060.json
# movie_reviews_25080.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_25080.json
# movie_reviews_25100.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_25100.json
# movie_reviews_25120.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_25120.json
# movie_reviews_25140.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_25140.json
# movie_reviews_25160.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_25160.json
# movie_reviews_25180.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_25180.json
# movie_reviews_25200.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_25200.json
# movie_reviews_25220.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_25220.json
# movie_reviews_25240.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_25240.json
# movie_reviews_25260.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_25260.json
# movie_reviews_25280.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_25280.json
# movie_reviews_25300.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_25300.json
# movie_reviews_25320.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_25320.json
# movie_reviews_25340.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_25340.json
# movie_reviews_25360.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_25360.json
# movie_reviews_25380.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_25380.json
# movie_reviews_25400.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_25400.json
# movie_reviews_25420.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_25420.json
# movie_reviews_25440.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_25440.json
# movie_reviews_25460.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_25460.json
# movie_reviews_25480.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_25480.json
# movie_reviews_25500.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_25500.json
# movie_reviews_25520.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_25520.json
# movie_reviews_25540.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_25540.json
# movie_reviews_25560.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_25560.json
# movie_reviews_25580.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_25580.json
# movie_reviews_25600.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_25600.json
# movie_reviews_25620.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_25620.json
# movie_reviews_25640.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_25640.json
# movie_reviews_25660.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_25660.json
# movie_reviews_25680.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_25680.json
# movie_reviews_25700.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_25700.json
# movie_reviews_25720.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_25720.json
# movie_reviews_25740.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_25740.json
# movie_reviews_25760.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_25760.json
# movie_reviews_25780.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_25780.json
# movie_reviews_25800.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_25800.json
# movie_reviews_25820.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_25820.json
# movie_reviews_25840.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_25840.json
# movie_reviews_25860.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_25860.json
# movie_reviews_25880.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_25880.json
# movie_reviews_25900.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_25900.json
# movie_reviews_25920.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_25920.json
# movie_reviews_25940.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_25940.json
# movie_reviews_25960.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_25960.json
# movie_reviews_25980.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_25980.json
# movie_reviews_26000.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_26000.json
# movie_reviews_26020.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_26020.json
# movie_reviews_26040.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_26040.json
# movie_reviews_26060.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_26060.json
# movie_reviews_26080.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_26080.json
# movie_reviews_26100.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_26100.json
# movie_reviews_26120.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_26120.json
# movie_reviews_26140.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_26140.json
# movie_reviews_26160.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_26160.json
# movie_reviews_26180.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_26180.json
# movie_reviews_26200.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_26200.json
# movie_reviews_26220.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_26220.json
# movie_reviews_26240.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_26240.json
# movie_reviews_26260.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_26260.json
# movie_reviews_26280.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_26280.json
# movie_reviews_26300.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_26300.json
# movie_reviews_26320.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_26320.json
# movie_reviews_26340.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_26340.json
# movie_reviews_26360.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_26360.json
# movie_reviews_26380.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_26380.json
# movie_reviews_26400.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_26400.json
# movie_reviews_26420.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_26420.json
# movie_reviews_26440.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_26440.json
# movie_reviews_26460.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_26460.json
# movie_reviews_26480.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_26480.json
# movie_reviews_26500.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_26500.json
# movie_reviews_26520.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_26520.json
# movie_reviews_26540.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_26540.json
# movie_reviews_26560.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_26560.json
# movie_reviews_26580.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_26580.json
# movie_reviews_26600.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_26600.json
# movie_reviews_26620.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_26620.json
# movie_reviews_26640.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_26640.json
# movie_reviews_26660.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_26660.json
# movie_reviews_26680.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_26680.json
# movie_reviews_26700.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_26700.json
# movie_reviews_26720.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_26720.json
# movie_reviews_26740.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_26740.json
# movie_reviews_26760.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_26760.json
# movie_reviews_26780.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_26780.json
# movie_reviews_26800.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_26800.json
# movie_reviews_26820.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_26820.json
# movie_reviews_26840.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_26840.json
# movie_reviews_26860.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_26860.json
# movie_reviews_26880.json
# resolve_nyt_json(): returning value from cache file: .\data\raw_data\movie_reviews\movie_reviews_26880.json
# Finished
