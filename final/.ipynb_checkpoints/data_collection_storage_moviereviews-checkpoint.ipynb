# %%
# Import the modules we need.
from bs4 import BeautifulSoup
from bs4 import SoupStrainer
import datetime
from glob import glob
import json
import os
import re
import requests
import string
import sys
import time


# Path to the data directory into which downloaded JSON is saved.
data_path = os.path.join(".", "data", "raw_data", "movie_reviews")
print(data_path)

# Check for whether os.path exists or not, if not create the dicrectory path
if not os.path.exists(data_path):
    print("Creating data directory: {}".format(data_path))
    os.makedirs(data_path)

if os.path.isdir(data_path):
    print(data_path + " is a directory")
else:
    print(data_path + " is NOT a directory - something is wrong :(")


# NYT API Key needs to be set in the environment before running this notebook.
nyt_archive_key = os.getenv('nyt_archive_key')
#print(nyt_archive_key)

if (nyt_archive_key is None) or (nyt_archive_key == ''):
    print("NYT API key is missing - it should be in an environment variable named 'nyt_archive_key'")
# Out:
# .\data\raw_data\movie_reviews
# .\data\raw_data\movie_reviews is a directory

# %%
# General-purpose utility function for saving an object as JSON to the data directory.
def save_to_json(obj, save_file_path):
    print("saving to file: " + save_file_path)

    with open(save_file_path, "wt") as f:
        json.dump(obj, f)
        
# General function for getting JSON, either by downloading or from a cache file.
def resolve_nyt_json(url, cache_file, request_params={}):
    if os.path.isfile(cache_file):
        # Cache file exists, so use that.
        result = {}
        with open(cache_file, 'rt') as f:
            try:
                result = json.load(f)
            except ValueError:
                result = {}
                
        print("resolve_nyt_json(): returning value from cache file: " + cache_file)
        return result

    # It's not in the cache, so download and save it.
    print("resolve_nyt_json(): downloading from NYT API")

    response = requests.get(url, params=request_params)
    print(response.status_code)
        
    # Sleep after a request, to avoid being rate-limited by the NYT servers.
    time.sleep(5)
    
    if 200 == response.status_code:
        save_to_json(response.json(), cache_file)
    else:
        print("resolve_nyt_json(): error downloading from NYT API ({code})".format(code=response.status_code))
        return {}
        
    return response.json()

# %%
# URL for calls to movies/v7/reviews
def get_movie_reviews_url():
    return "https://api.nytimes.com/svc/movies/v2/reviews/all.json"

# Name of the cache file for calls to reviews/search.
def get_movie_reviews_cache_file_path(offset):
    filename = "movie_reviews_{offset}.json".format(offset=offset)
    print(filename)
    return os.path.join(data_path, filename)

# Name of the cache file for calls to reviews/search.
def get_movie_reviews_params(offset):
    return {'api-key':nyt_archive_key, 
            'offset':offset}

# Convenience routine for getting the result of movie reviews search.
def resolve_movie_reviews(offset):
    return resolve_nyt_json(get_movie_reviews_url(), 
                            get_movie_reviews_cache_file_path(offset), 
                            get_movie_reviews_params(offset))

# %%
# set offset to deal with rate limied 
offset = 0
has_more_reviews = True
while has_more_reviews:
    response = resolve_movie_reviews(offset)
    try:
        has_more_reviews = response['has_more']
        offset += 20
    except:
        # Probably got rate-limited. Sleep and try again...
        time.sleep(60)
    
print("Finished")
# Out:
# movie_reviews_26000.json
# resolve_nyt_json(): downloading from NYT API
# 200
# saving to file: .\data\raw_data\movie_reviews\movie_reviews_26000.json
# movie_reviews_26020.json
# resolve_nyt_json(): downloading from NYT API
# 200
# saving to file: .\data\raw_data\movie_reviews\movie_reviews_26020.json
# movie_reviews_26040.json
# resolve_nyt_json(): downloading from NYT API
# 200
# saving to file: .\data\raw_data\movie_reviews\movie_reviews_26040.json
# movie_reviews_26060.json
# resolve_nyt_json(): downloading from NYT API
# 200
# saving to file: .\data\raw_data\movie_reviews\movie_reviews_26060.json
# movie_reviews_26080.json
# resolve_nyt_json(): downloading from NYT API
# 200
# saving to file: .\data\raw_data\movie_reviews\movie_reviews_26080.json
# movie_reviews_26100.json
# resolve_nyt_json(): downloading from NYT API
# 200
# saving to file: .\data\raw_data\movie_reviews\movie_reviews_26100.json
# movie_reviews_26120.json
# resolve_nyt_json(): downloading from NYT API
# 200
# saving to file: .\data\raw_data\movie_reviews\movie_reviews_26120.json
# movie_reviews_26140.json
# resolve_nyt_json(): downloading from NYT API
# 200
# saving to file: .\data\raw_data\movie_reviews\movie_reviews_26140.json
# movie_reviews_26160.json
# resolve_nyt_json(): downloading from NYT API
# 200
# saving to file: .\data\raw_data\movie_reviews\movie_reviews_26160.json
# movie_reviews_26180.json
# resolve_nyt_json(): downloading from NYT API
# 200
# saving to file: .\data\raw_data\movie_reviews\movie_reviews_26180.json
# movie_reviews_26200.json
# resolve_nyt_json(): downloading from NYT API
# 200
# saving to file: .\data\raw_data\movie_reviews\movie_reviews_26200.json
# movie_reviews_26220.json
# resolve_nyt_json(): downloading from NYT API
# 200
# saving to file: .\data\raw_data\movie_reviews\movie_reviews_26220.json
# movie_reviews_26240.json
# resolve_nyt_json(): downloading from NYT API
# 200
# saving to file: .\data\raw_data\movie_reviews\movie_reviews_26240.json
# movie_reviews_26260.json
# resolve_nyt_json(): downloading from NYT API
# 200
# saving to file: .\data\raw_data\movie_reviews\movie_reviews_26260.json
# movie_reviews_26280.json
# resolve_nyt_json(): downloading from NYT API
# 200
# saving to file: .\data\raw_data\movie_reviews\movie_reviews_26280.json
# movie_reviews_26300.json
# resolve_nyt_json(): downloading from NYT API
# 200
# saving to file: .\data\raw_data\movie_reviews\movie_reviews_26300.json
# movie_reviews_26320.json
# resolve_nyt_json(): downloading from NYT API
# 200
# saving to file: .\data\raw_data\movie_reviews\movie_reviews_26320.json
# movie_reviews_26340.json
# resolve_nyt_json(): downloading from NYT API
# 200
# saving to file: .\data\raw_data\movie_reviews\movie_reviews_26340.json
# movie_reviews_26360.json
# resolve_nyt_json(): downloading from NYT API
# 200
# saving to file: .\data\raw_data\movie_reviews\movie_reviews_26360.json
# movie_reviews_26380.json
# resolve_nyt_json(): downloading from NYT API
# 200
# saving to file: .\data\raw_data\movie_reviews\movie_reviews_26380.json
# movie_reviews_26400.json
# resolve_nyt_json(): downloading from NYT API
# 200
# saving to file: .\data\raw_data\movie_reviews\movie_reviews_26400.json
# movie_reviews_26420.json
# resolve_nyt_json(): downloading from NYT API
# 200
# saving to file: .\data\raw_data\movie_reviews\movie_reviews_26420.json
# movie_reviews_26440.json
# resolve_nyt_json(): downloading from NYT API
# 200
# saving to file: .\data\raw_data\movie_reviews\movie_reviews_26440.json
# movie_reviews_26460.json
# resolve_nyt_json(): downloading from NYT API
# 200
# saving to file: .\data\raw_data\movie_reviews\movie_reviews_26460.json
# movie_reviews_26480.json
# resolve_nyt_json(): downloading from NYT API
# 200
# saving to file: .\data\raw_data\movie_reviews\movie_reviews_26480.json
# movie_reviews_26500.json
# resolve_nyt_json(): downloading from NYT API
# 200
# saving to file: .\data\raw_data\movie_reviews\movie_reviews_26500.json
# movie_reviews_26520.json
# resolve_nyt_json(): downloading from NYT API
# 200
# saving to file: .\data\raw_data\movie_reviews\movie_reviews_26520.json
# movie_reviews_26540.json
# resolve_nyt_json(): downloading from NYT API
# 200
# saving to file: .\data\raw_data\movie_reviews\movie_reviews_26540.json
# movie_reviews_26560.json
# resolve_nyt_json(): downloading from NYT API
# 200
# saving to file: .\data\raw_data\movie_reviews\movie_reviews_26560.json
# movie_reviews_26580.json
# resolve_nyt_json(): downloading from NYT API
# 200
# saving to file: .\data\raw_data\movie_reviews\movie_reviews_26580.json
# movie_reviews_26600.json
# resolve_nyt_json(): downloading from NYT API
# 200
# saving to file: .\data\raw_data\movie_reviews\movie_reviews_26600.json
# movie_reviews_26620.json
# resolve_nyt_json(): downloading from NYT API
# 200
# saving to file: .\data\raw_data\movie_reviews\movie_reviews_26620.json
# movie_reviews_26640.json
# resolve_nyt_json(): downloading from NYT API
# 200
# saving to file: .\data\raw_data\movie_reviews\movie_reviews_26640.json
# movie_reviews_26660.json
# resolve_nyt_json(): downloading from NYT API
# 200
# saving to file: .\data\raw_data\movie_reviews\movie_reviews_26660.json
# movie_reviews_26680.json
# resolve_nyt_json(): downloading from NYT API
# 200
# saving to file: .\data\raw_data\movie_reviews\movie_reviews_26680.json
# movie_reviews_26700.json
# resolve_nyt_json(): downloading from NYT API
# 200
# saving to file: .\data\raw_data\movie_reviews\movie_reviews_26700.json
# movie_reviews_26720.json
# resolve_nyt_json(): downloading from NYT API
# 200
# saving to file: .\data\raw_data\movie_reviews\movie_reviews_26720.json
# movie_reviews_26740.json
# resolve_nyt_json(): downloading from NYT API
# 200
# saving to file: .\data\raw_data\movie_reviews\movie_reviews_26740.json
# movie_reviews_26760.json
# resolve_nyt_json(): downloading from NYT API
# 200
# saving to file: .\data\raw_data\movie_reviews\movie_reviews_26760.json
# movie_reviews_26780.json
# resolve_nyt_json(): downloading from NYT API
# 200
# saving to file: .\data\raw_data\movie_reviews\movie_reviews_26780.json
# movie_reviews_26800.json
# resolve_nyt_json(): downloading from NYT API
# 200
# saving to file: .\data\raw_data\movie_reviews\movie_reviews_26800.json
# movie_reviews_26820.json
# resolve_nyt_json(): downloading from NYT API
# 200
# saving to file: .\data\raw_data\movie_reviews\movie_reviews_26820.json
# movie_reviews_26840.json
# resolve_nyt_json(): downloading from NYT API
# 200
# saving to file: .\data\raw_data\movie_reviews\movie_reviews_26840.json
# movie_reviews_26860.json
# resolve_nyt_json(): downloading from NYT API
# 200
# saving to file: .\data\raw_data\movie_reviews\movie_reviews_26860.json
# movie_reviews_26880.json
# resolve_nyt_json(): downloading from NYT API
# 200
# saving to file: .\data\raw_data\movie_reviews\movie_reviews_26880.json
# Finished
