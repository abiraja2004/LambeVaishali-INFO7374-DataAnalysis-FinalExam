# %% [markdown]
# # Data cleaning
#
# This script:
#
# * extracts the reviews from each file in the data directory (default: "./data/raw_data/movie_reviews")
# * cleans up data in each file:
#   * convert critics_pick to a boolean type
#   * remove unnecessary columns ('link' and 'multimedia')
#   * replaces opening dates of '0000-00-00' with None
#   * convert date columns to datetime type
#   * remove newlines and carriage returns from the summary
# * combines them into a single data frame
# * saves the combined data frame to the output file (default: "/cleaned_data/movie_reviews.csv").

# %%
import numpy as np
import pandas as pd
import json
import os


# Path to the data directory into which downloaded JSON is saved.
data_path = os.path.join(".", "data", "raw_data", "movie_reviews")
print(data_path)

if not os.path.exists(data_path):
    print("Creating data directory: {}".format(data_path))
    os.makedirs(data_path)

if os.path.isdir(data_path):
    print(data_path + " is a directory")
else:
    print(data_path + " is NOT a directory - something is wrong :(")

    
# Path to the output directory.
csv_file_path = os.path.join(".", "cleaned_data", "movie_reviews.csv")

if not os.path.exists(csv_file_path):
    print("Creating data directory: {}".format(csv_file_path))
    os.makedirs(csv_file_path)
# Out:
# .\data\raw_data\movie_reviews
# .\data\raw_data\movie_reviews is a directory

# %%
# Utility function to get the list of raw data JSON file paths.
#
# d - directory to search in
# suffix - only return files ending with this suffix, defaults to ".json"
# returns a list of files 
def get_raw_json_file_paths(d, suffix='.json'):
    
    filelist = [f for f in os.listdir(d) if 
                os.path.isfile(os.path.join(d, f)) and f.endswith(suffix)]
    
    return filelist

# %%
# Utility function to restore the datetime type to date columns.
#
# df - dataframe to adjust
# returns dataframe with date columns as datetime types
def restore_date_columns(df):
    # Convert dates from object/string into datetime.
    df['publication_date'] = pd.to_datetime(df['publication_date'])
    df['date_updated'] = pd.to_datetime(df['date_updated'])

    # opening_date has some 'interesting' data (e.g. 1998-00-00) so leave that alone for now.
    #df['opening_date'] = pd.to_datetime(df['opening_date'])

    # Clean up any dates with the value "0000-00-00".
    df.loc[df['opening_date'] == "0000-00-00", ['opening_date']] = None
    
    return df
    

# Function to create a dataframe from a raw data file.
#
# The raw data file includes metadata from the server; this is excluded from the dataframe.
#
# f - path to raw data file
# returns dataframe created from results in raw data file
def create_data_frame(f, verbose=False):
    if verbose:
        print("create_data_frame() - filename: {}".format(f))
    
    # Read the object.
    reviews = None
    with open(f, "rt", encoding="UTF-8") as json_data:
        reviews = json.load(json_data)
        if verbose:
            print(reviews)

    reviews = reviews['results']
    if verbose:
        print(reviews)
    
    # Turn it into a data frame.
    result = pd.DataFrame(reviews)
    if verbose:
        print(result.shape)
        print(result.head(20))

    
    # Convert critics_pick from float to boolean.
    result['critics_pick'] = result['critics_pick'].astype(bool)

    # Punctuation is inconsistent in this field, so remove it.
    result['byline'] = result['byline'].str.replace('.', ' ')
    result['byline'] = result['byline'].str.replace('-', ' ')
    result['byline'] = result['byline'].str.replace('_', ' ')
    result['byline'] = result['byline'].str.replace('%', ' ')
    result['byline'] = result['byline'].str.replace(':', ' ')
    result['byline'] = result['byline'].str.replace(']', ' ')
    result['byline'] = result['byline'].str.replace('[', ' ')

    # Some bylines end with a comma; remove it.
    result.loc[result['byline'].str.endswith(','), ['byline']] = result['byline'].str[:-1]
    
    # Collapse runs of whitespace.
    result['byline'] = result['byline'].str.replace('    ', ' ')
    result['byline'] = result['byline'].str.replace('   ', ' ')
    result['byline'] = result['byline'].str.replace('  ', ' ')

    # Remove leading and trailing whitespace.
    result['byline'] = result['byline'].str.strip()

    # Bylines are mixed case, so convert to title case.
    result['byline'] = result['byline'].str.title()

    # These poor fellows have their names misspelled terribly.
    result.loc[result['byline'] == "Moroaunt Hall", ['byline']] = "Mordaunt Hall"
    result.loc[result['byline'] == "Mokdaunt Hall", ['byline']] = "Mordaunt Hall"
    result.loc[result['byline'] == "Modaunt Hall", ['byline']] = "Mordaunt Hall"
    result.loc[result['byline'] == "Modaut Hall", ['byline']] = "Mordaunt Hall"
    result.loc[result['byline'] == "Mordaut Hall", ['byline']] = "Mordaunt Hall"

    result.loc[result['byline'] == "Bosuey Crowther", ['byline']] = "Bosley Crowther"
    result.loc[result['byline'] == "Bossley Crowther", ['byline']] = "Bosley Crowther"
    result.loc[result['byline'] == "Bosley Chowther", ['byline']] = "Bosley Crowther"
    
    result.loc[result['byline'] == "Andrbe Sennwald", ['byline']] = "Andre Sennwald"
    result.loc[result['byline'] == "Andre Senn Wald", ['byline']] = "Andre Sennwald"

    
    # Some summaries end in newline characters, some contain carriage returns and newlines.
    result['summary_short'] = result['summary_short'].str.strip()
    result['summary_short'] = result['summary_short'].str.replace('\r', '')
    result['summary_short'] = result['summary_short'].str.replace('\n', '')

    
    # Convert dates from object/string into datetime.
    result = restore_date_columns(result)
    
    # Drop link (URL to full review) and multimedia (image) since we don't care about those.
    return result.drop(['link', 'multimedia'], axis=1)

# %%
# Function to create a combined CSV file from a list of dataframes
#
# df_list - list of dataframes to combine and write
# outfilepath - path to the CSV file to write
# returns nothing
def create_combined_csv(df_list, outfilepath):
    
    combined_df = pd.concat(df_list)
    print(combined_df.shape)
    
    # QUOTE_NONNUMERIC (2) because we expect commas to be present in text fields.
    combined_df.to_csv(outfilepath, index=False, quoting=2, encoding="UTF-8")

# %%
raw_data_file_names = get_raw_json_file_paths(data_path)
dataframes = [create_data_frame(os.path.join(data_path, f), verbose=False) for f in raw_data_file_names]
print("Loaded {} dataframes".format(len(dataframes)))
# Out:
# Loaded 1345 dataframes

# %%
# Write the combined CSV file.
create_combined_csv(dataframes, csv_file_path)

# And read it back in.
restored_df = pd.read_csv(csv_file_path, quoting=2, parse_dates=True, infer_datetime_format=True, encoding="UTF-8")
restored_df = restore_date_columns(restored_df)

print(restored_df.shape)
print(restored_df.info())
print(restored_df.head(20))
# Out:
# (26893, 9)
# (26893, 9)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26893 entries, 0 to 26892
# Data columns (total 9 columns):
# byline              26893 non-null object
# critics_pick        26893 non-null bool
# date_updated        26878 non-null datetime64[ns]
# display_title       26893 non-null object
# headline            26893 non-null object
# mpaa_rating         13516 non-null object
# opening_date        16971 non-null object
# publication_date    26893 non-null datetime64[ns]
# summary_short       20764 non-null object
# dtypes: bool(1), datetime64[ns](2), object(6)
# memory usage: 1.7+ MB
# None
#                  byline critics_pick        date_updated  \
# 0        Manohla Dargis         True 2017-04-18 16:44:22
# 1             A O Scott         True 2017-04-18 16:44:21
# 2             A O Scott         True 2017-04-18 16:44:21
# 3   Jeannette Catsoulis        False 2017-04-18 16:44:26
# 4           Glenn Kenny        False 2017-04-13 21:58:02
# 5   Jeannette Catsoulis        False 2017-04-18 16:44:25
# 6        Ken Jaworowski        False 2017-04-18 16:44:25
# 7       Neil Genzlinger        False 2017-04-18 16:44:24
# 8        Ken Jaworowski        False 2017-04-18 16:44:24
# 9        Ben Kenigsberg        False 2017-04-18 16:44:23
# 10       Ben Kenigsberg        False 2017-04-18 16:44:23
# 11       Ben Kenigsberg        False 2017-04-18 16:44:23
# 12  Jeannette Catsoulis        False 2017-04-18 16:44:22
# 13       Manohla Dargis        False 2017-04-18 16:44:21
# 14          Glenn Kenny         True 2017-04-18 16:44:20
# 15       Manohla Dargis         True 2017-04-18 16:44:18
# 16            A O Scott         True 2017-04-18 16:44:17
# 17         Andy Webster        False 2017-04-18 16:44:20
# 18      Neil Genzlinger        False 2017-04-14 16:44:02
# 19      Neil Genzlinger        False 2017-04-18 16:44:19
#
#                                    display_title  \
# 0                             The Lost City of Z
# 1                                A Quiet Passion
# 2                                         Norman
# 3                                 Tommy's Honour
# 4     My Entire High School Sinking Into the Sea
# 5                                        Mimosas
# 6               Maurizio Cattelan: Be Right Back
# 7                                   Little Boxes
# 8                                  Finding Oscar
# 9   Chasing Trane: The John Coltrane Documentary
# 10                      By the Time It Gets Dark
# 11                    All These Sleepless Nights
# 12                               Heal the Living
# 13                       The Fate of the Furious
# 14                                         Glory
# 15                                     Your Name
# 16                                    Graduation
# 17                           The Transfiguration
# 18                               Speech & Debate
# 19                                Going in Style
#
#                                              headline mpaa_rating  \
# 0   Review: Hearts of Darkness and Light in ‘The L...       PG-13
# 1   Review: ‘A Quiet Passion’ Poetically Captures ...       PG-13
# 2   Review: Richard Gere as ‘Norman,’ an Aspiratio...           R
# 3   Review: In ‘Tommy’s Honour,’ a Family Feud on ...          PG
# 4   Review: Angst, Jealousy and ‘My Entire High Sc...       PG-13
# 5       Review: In ‘Mimosas,’ a Cryptic Mountain Trek         NaN
# 6   Review: ‘Maurizio Cattelan: Be Right Back’ Rel...         NaN
# 7   Review: In ‘Little Boxes,’ a Biracial Family M...         NaN
# 8   Review: ‘Finding Oscar,’ and Hope, in Massacre...         NaN
# 9   Review: In ‘Chasing Trane,’ Where’s the Joy of...         NaN
# 10  Review: A Fragmented Past in ‘By the Time It G...         NaN
# 11  Review: ‘All These Sleepless Nights’ Roams the...           R
# 12  Review: ‘Heal the Living,’ a Sentimental Sales...         NaN
# 13  Review: Family Values and Hot Rides in ‘Fate o...       PG-13
# 14  Review: The ‘Glory’ of a Good Deed (and Its Fa...         NaN
# 15  Review: ‘Your Name’ Takes Adolescent Identity ...          PG
# 16  Review: ‘Graduation’ and the Anguish of Living...           R
# 17  Review: In ‘The Transfiguration,’ Coping With ...         NaN
# 18  Review: 3 Teenagers Seek a Voice in ‘Speech & ...       PG-13
# 19  Review: ‘Going in Style’ Proves Crime Has No A...       PG-13
#
#    opening_date publication_date  \
# 0    2017-04-14       2017-04-13
# 1           NaN       2017-04-13
# 2    2017-04-14       2017-04-13
# 3    2017-04-14       2017-04-13
# 4           NaN       2017-04-13
# 5           NaN       2017-04-13
# 6    2016-04-01       2017-04-13
# 7    2017-04-14       2017-04-13
# 8    2017-04-14       2017-04-13
# 9    2017-04-14       2017-04-13
# 10          NaN       2017-04-13
# 11   2017-04-07       2017-04-13
# 12          NaN       2017-04-13
# 13   2017-04-14       2017-04-12
# 14          NaN       2017-04-11
# 15   2017-04-07       2017-04-06
# 16          NaN       2017-04-06
# 17          NaN       2017-04-06
# 18   2017-04-07       2017-04-06
# 19   2017-04-07       2017-04-06
#
#                                         summary_short
# 0   Charlie Hunnam stars in this period adventure ...
# 1   Cynthia Nixon brings a great 19th-century Amer...
# 2   ‘Norman: The Moderate Rise and Tragic Fall of ...
# 3   The director Jason Connery’s staid biopic is a...
# 4   Teenage anxiety (voiced by Dash Shaw, Lena Dun...
# 5   In following nomads on a mission in Morocco, t...
# 6   The documentary explores the artworks and pran...
# 7   A family ventures beyond the bubble of gentrif...
# 8   This documentary looks at a Guatemalan village...
# 9   John Scheinfeld’s documentary about John Coltr...
# 10  In examining a violent suppression of universi...
# 11  A Polish film follows its young protagonist as...
# 12  Life, death and a heart transplant are at the ...
# 13  Each installment of “Fast and Furious” is more...
# 14  A railroad worker dutifully turns in the cash ...
# 15  Manohla Dargis reviews Makoto Shinkai’s latest...
# 16  An excruciating ethical problem arises for a m...
# 17  A New York teenager in low-income housing trie...
# 18  Stephen Karam’s film adaptation of his own pla...
# 19  Michael Caine, Alan Arkin and Morgan Freeman s...

# %%
restored_df.describe()
# Out:
#                  byline critics_pick         date_updated display_title  \
# count             26893        26893                26878         26893
# unique              301            2                 3359         25744
# top     Bosley Crowther        False  2016-09-23 12:44:01        Hamlet
# freq               3022        23766                   16             7
# first               NaN          NaN  2016-03-30 06:41:07           NaN
# last                NaN          NaN  2017-04-18 16:44:26           NaN
#
#         headline mpaa_rating opening_date     publication_date summary_short
# count      26893       13516        16971                26893         20764
# unique     26656           7         8064                12692         20718
# top     Devotion           R   2014-01-10  2013-10-17 00:00:00      Routine.
# freq           4        5948           16                   25             6
# first        NaN         NaN          NaN  1915-10-20 00:00:00           NaN
# last         NaN         NaN          NaN  2017-04-13 00:00:00           NaN

# %%
print(restored_df['critics_pick'].value_counts())
print(restored_df['byline'].value_counts())
# Out:
# False    23766
# True      3127
# Name: critics_pick, dtype: int64
# Bosley Crowther                                                 3022
# Stephen Holden                                                  2931
# Janet Maslin                                                    2696
# Vincent Canby                                                   2601
# A O Scott                                                       1790
# Mordaunt Hall                                                   1350
# Jeannette Catsoulis                                             1180
# Manohla Dargis                                                  1142
# Neil Genzlinger                                                  545
# Howard Thompson                                                  536
# Caryn James                                                      527
# Frank S Nugent                                                   511
# 26863                                    Tokyo Eyes
# 26864                                        Barrio
# 26865                                     Buttoners
# 26866                                Dribbling Fate
# 26867                              Cookie's Fortune
# 26868                                       Paulina
# 26869                                     Following
# 26870                            The Out-Of-Towners
# 26871                                    The Wounds
# 26872                               Thrane's Method
# 26873              Encounter in the Third Dimension
# 26874                     The Underground Orchestra
# 26875                                    The Matrix
# 26876                                   Open Bodies
# 26877                                       Passion
# 26878                                        Victor
# 26879                          Birth of a Butterfly
# 26880                                   West Beirut
# 26881                             Of Freaks and Men
# 26882                                   Judy Berlin
# 26883                                          Edtv
# 26884                            A Walk on the Moon
# 26885                                          Hard
# 26886                            Doug's First Movie
# 26887                                  Run Lola Run
# 26888                        Sticky Fingers of Time
# 26889                                  Among Giants
# 26890                                 The Mod Squad
# 26891                                    True Crime
# 26892                                The King and I
#
#                                                 headline mpaa_rating  \
# 0      Review: Hearts of Darkness and Light in ‘The L...       PG-13
# 1      Review: ‘A Quiet Passion’ Poetically Captures ...       PG-13
# 2      Review: Richard Gere as ‘Norman,’ an Aspiratio...           R
# 3      Review: In ‘Tommy’s Honour,’ a Family Feud on ...          PG
# 4      Review: Angst, Jealousy and ‘My Entire High Sc...       PG-13
# 5          Review: In ‘Mimosas,’ a Cryptic Mountain Trek         NaN
# 6      Review: ‘Maurizio Cattelan: Be Right Back’ Rel...         NaN
# 7      Review: In ‘Little Boxes,’ a Biracial Family M...         NaN
# 8      Review: ‘Finding Oscar,’ and Hope, in Massacre...         NaN
# 9      Review: In ‘Chasing Trane,’ Where’s the Joy of...         NaN
# 10     Review: A Fragmented Past in ‘By the Time It G...         NaN
# 11     Review: ‘All These Sleepless Nights’ Roams the...           R
# 12     Review: ‘Heal the Living,’ a Sentimental Sales...         NaN
# 13     Review: Family Values and Hot Rides in ‘Fate o...       PG-13
# 14     Review: The ‘Glory’ of a Good Deed (and Its Fa...         NaN
# 15     Review: ‘Your Name’ Takes Adolescent Identity ...          PG
# 16     Review: ‘Graduation’ and the Anguish of Living...           R
# 17     Review: In ‘The Transfiguration,’ Coping With ...         NaN
# 18     Review: 3 Teenagers Seek a Voice in ‘Speech & ...       PG-13
# 19     Review: ‘Going in Style’ Proves Crime Has No A...       PG-13
# 20     Review: ‘Before I Fall,’ a Melodramatic ‘Groun...       PG-13
# 21     Review: In ‘Wolves,’ a High School Athlete Can...         NaN
# 22     Review: ‘Kiki’: The Vogueing Scene, Still a Re...         NaN
# 23     Review: ‘Contemporary Color,’ David Byrne’s Od...       PG-13
# 24     Review: In ‘Get Out,’ Guess Who’s Coming to Di...           R
# 25     Review: ‘Les Hautes Solitudes,’ the Silent Sid...         NaN
# 26     Review: ‘Dying Laughing,’ About Bombing Onstag...         NaN
# 27     Review: ‘The Girl With All the Gifts,’ and an ...           R
# 28     Review: ‘Punching Henry,’ a Nice Guy Who’s Jus...         NaN
# 29     Review: In ‘As You Are,’ a Nod to Nirvana, and...         NaN
# ...                                                  ...         ...
# 26863                               Tokyo Eyes (Movie)           NaN
# 26864                                   Barrio (Movie)           NaN
# 26865                                Buttoners (Movie)           NaN
# 26866                           Dribbling Fate (Movie)           NaN
# 26867                         Cookie's Fortune (Movie)         PG-13
# 26868                                  Paulina (Movie)           NaN
# 26869                                Following (Movie)             R
# 26870                      Out-of-Towners, The (Movie)         PG-13
# 26871                              Wounds, The (Movie)           NaN
# 26872                          Thrane's Method (Movie)           NaN
# 26873         Encounter in the Third Dimension (Movie)           NaN
# 26874               Underground Orchestra, The (Movie)           NaN
# 26875                              Matrix, The (Movie)             R
# 26876                                Open Bodies (Movie)         NaN
# 26877                                  Passion (Movie)           NaN
# 26878                                   Victor (Movie)           NaN
# 26879                     Birth of a Butterfly (Movie)           NaN
# 26880                              West Beirut (Movie)         PG-13
# 26881                        Of Freaks and Men (Movie)           NaN
# 26882                              Judy Berlin (Movie)           NaN
# 26883                                     Edtv (Movie)         PG-13
# 26884                        Walk on the Moon, A (Movie)           R
# 26885                                     Hard (Movie)             R
# 26886                       Doug's First Movie (Movie)             G
# 26887                             Run Lola Run (Movie)             R
# 26888              Sticky Fingers of Time, The (Movie)           NaN
# 26889                             Among Giants (Movie)             R
# 26890                             Mod Squad, The (Movie)           R
# 26891                               True Crime (Movie)             R
# 26892                          King and I, The (Movie)             G
#
#               opening_date publication_date  \
# 0               2017-04-14       2017-04-13
# 1      1492041600000000000       2017-04-13
# 2               2017-04-14       2017-04-13
# 3               2017-04-14       2017-04-13
# 4      1492041600000000000       2017-04-13
# 5      1492041600000000000       2017-04-13
# 6               2016-04-01       2017-04-13
# 7               2017-04-14       2017-04-13
# 8               2017-04-14       2017-04-13
# 9               2017-04-14       2017-04-13
# 10     1492041600000000000       2017-04-13
# 11              2017-04-07       2017-04-13
# 12     1492041600000000000       2017-04-13
# 13              2017-04-14       2017-04-12
# 14     1491868800000000000       2017-04-11
# 15              2017-04-07       2017-04-06
# 16     1491436800000000000       2017-04-06
# 17     1491436800000000000       2017-04-06
# 18              2017-04-07       2017-04-06
# 19              2017-04-07       2017-04-06
# 20              2017-03-03       2017-03-01
# 21              2017-03-03       2017-03-01
# 22              2017-03-01       2017-02-28
# 23     1488240000000000000       2017-02-28
# 24              2017-02-24       2017-02-23
# 25     1487808000000000000       2017-02-23
# 26              2017-02-24       2017-02-23
# 27     1487808000000000000       2017-02-23
# 28     1487808000000000000       2017-02-23
# 29              2017-02-24       2017-02-23
# ...                    ...              ...
# 26863           2001-07-27       1999-04-03
# 26864   923097600000000000       1999-04-03
# 26865   923097600000000000       1999-04-03
# 26866   923097600000000000       1999-04-03
# 26867           1999-04-16       1999-04-02
# 26868           1999-01-04       1999-04-02
# 26869   923011200000000000       1999-04-02
# 26870           1999-04-02       1999-04-02
# 26871   922924800000000000       1999-04-01
# 26872   922924800000000000       1999-04-01
# 26873           1999-03-31       1999-03-31
# 26874   922838400000000000       1999-03-31
# 26875           1999-03-31       1999-03-31
# 26876   922752000000000000       1999-03-30
# 26877   922752000000000000       1999-03-30
# 26878   922492800000000000       1999-03-27
# 26879   922492800000000000       1999-03-27
